# %%
from pybaseball import statcast
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = statcast('2017-05-01', '2017-06-30')
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [02:09<00:00,  2.12s/it]

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2571         CU 2017-06-30           81.7          -1.83            5.6
# 2640         CU 2017-06-30           80.3          -1.44           5.73
# 2693         FF 2017-06-30           96.6          -1.66           5.84
# 2780         CU 2017-06-30           79.3          -1.63            5.6
# 2861         FF 2017-06-30           96.0          -1.63           5.74
# ...         ...        ...            ...            ...            ...
# 2822         FF 2017-05-01           93.7          -1.14           5.84
# 2944         FF 2017-05-01           93.3          -1.36           5.92
# 2975         SI 2017-05-01           89.4          -1.18           6.21
# 3053         SI 2017-05-01           89.0          -1.24           6.13
# 3150         SI 2017-05-01           88.3          -1.37            6.0
#
#           player_name  batter  pitcher     events              description  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data_sam=data[data["pitcher"]==592815]

# %%
data_sam
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2571         CU 2017-06-30           81.7          -1.83            5.6
# 2640         CU 2017-06-30           80.3          -1.44           5.73
# 2693         FF 2017-06-30           96.6          -1.66           5.84
# 2780         CU 2017-06-30           79.3          -1.63            5.6
# 2861         FF 2017-06-30           96.0          -1.63           5.74
# ...         ...        ...            ...            ...            ...
# 3164         FF 2017-05-04           95.3          -1.44           5.66
# 3221         SI 2017-05-04           94.2          -1.69           5.63
# 3343         CU 2017-05-04           81.5          -1.66           5.65
# 3411         SI 2017-05-04           94.2          -1.77           5.81
# 3536         FF 2017-05-04           96.4          -1.48           5.67
#
#           player_name  batter  pitcher     events              description  \
# ...

# %%
data_sam.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
data_sam_type=data_sam.groupby("pitch_type")["spin_axis"].mean

# %%
data_sam_type2=data_sam.loc[:,["pitch_type","spin_axis"]]

# %%
data_sam_type2
# Out:
#      pitch_type  spin_axis
# 2571         CU         54
# 2640         CU         65
# 2693         FF        208
# 2780         CU         65
# 2861         FF        220
# ...         ...        ...
# 3164         FF        213
# 3221         SI        235
# 3343         CU         42
# 3411         SI        236
# 3536         FF        210
#
# [246 rows x 2 columns]

# %%
data_sam_type2.describe()
# Out:
#         spin_axis
# count  246.000000
# mean   157.463415
# std     74.568888
# min     25.000000
# 25%     62.250000
# 50%    199.500000
# 75%    213.000000
# max    328.000000

# %%
data_sam_type_cu=data_sam_type2.loc[data_sam_type2["pitch_type"]=="CU"]

# %%
data_sam_type_cu.describe()
# Out:
#        spin_axis
# count  74.000000
# mean   55.837838
# std     9.720797
# min    25.000000
# 25%    52.000000
# 50%    56.500000
# 75%    62.000000
# max    78.000000

# %%
pd.unique(data_sam_type2["pitch_type"])
# Out:
# array(['CU', 'FF', 'SL', 'SI'], dtype=object)

# %%
data_sam_type_ff=data_sam_type2.loc[data_sam_type2["pitch_type"]=="FF"]

# %%
data_sam_type_ff
# Out:
#      pitch_type  spin_axis
# 2693         FF        208
# 2861         FF        220
# 2903         FF        194
# 2991         FF        200
# 3276         FF        196
# ...         ...        ...
# 3818         FF        185
# 4287         FF        209
# 4343         FF        204
# 3164         FF        213
# 3536         FF        210
#
# [121 rows x 2 columns]

# %%
data_sam_type_ff.describe()
# Out:
#         spin_axis
# count  121.000000
# mean   206.512397
# std      9.531628
# min    181.000000
# 25%    200.000000
# 50%    208.000000
# 75%    213.000000
# max    226.000000

# %%
data_sam_type_sl=data_sam_type2.loc[data_sam_type2["pitch_type"]=="SL"]

# %%
data_sam_type_sl
# Out:
#      pitch_type  spin_axis
# 3069         SL        129
# 3449         SL        166
# 3555         SL        162
# 3034         SL         59
# 3549         SL         65
# 3948         SL        147
# 4005         SL         59
# 4208         SL        162
# 2536         SL        104
# 3380         SL        127
# 2255         SL        328
# 2627         SL        145
# 2823         SL         62
# 2962         SL         66
# 3346         SL        235
# 3805         SL         49
# 4041         SL         57
# 4075         SL        121
# 2597         SL        107
# 2870         SL        141
# 3287         SL        170
# 3363         SL        226
# 3555         SL        178
# 2903         SL        160
# 2762         SL        194

# %%
data_sam_type_sl.describe()
# Out:
#         spin_axis
# count   25.000000
# mean   136.760000
# std     66.893747
# min     49.000000
# 25%     66.000000
# 50%    141.000000
# 75%    166.000000
# max    328.000000

# %%
data_sam.loc[data_sam.index==3805]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3805         SL 2017-06-16           87.6          -1.99           5.37
#
#           player_name  batter  pitcher events description  ...  fld_score  \
# 3805  Tuivailala, Sam  572241   592815    NaN        foul  ...         10
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3805               10                1               1              10
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3805              Standard              Standard        49                0.0
#
#      delta_run_exp
# 3805        -0.039
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==4041]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 4041         SL 2017-06-16           88.5           -1.9           5.34
#
#           player_name  batter  pitcher     events    description  ...  \
# 4041  Tuivailala, Sam  429666   592815  field_out  hit_into_play  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 4041         10               10                1               1
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 4041              10              Standard              Standard        57
#
#      delta_home_win_exp delta_run_exp
# 4041             -0.001        -0.235
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==3034]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3034         SL 2017-06-24           87.4          -1.53           5.33
#
#           player_name  batter  pitcher     events      description  ...  \
# 3034  Tuivailala, Sam  591741   592815  strikeout  swinging_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 3034          1                7                1               7
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 3034               1              Standard              Standard        59
#
#      delta_home_win_exp delta_run_exp
# 3034              0.001        -0.063
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==4005]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 4005         SL 2017-06-24           87.9          -1.66           5.59
#
#           player_name  batter  pitcher events      description  ...  \
# 4005  Tuivailala, Sam  474568   592815    NaN  swinging_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 4005          1                7                1               7
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 4005               1              Standard              Standard        59
#
#      delta_home_win_exp delta_run_exp
# 4005                0.0        -0.062
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==2255]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2255         SL 2017-06-16           88.5          -2.08           5.48
#
#           player_name  batter  pitcher    events    description  ...  \
# 2255  Tuivailala, Sam  641820   592815  home_run  hit_into_play  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 2255         11               11                2               2
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 2255              11              Standard              Standard       328
#
#      delta_home_win_exp delta_run_exp
# 2255                0.0         1.017
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==3363]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3363         SL 2017-05-21           90.4          -1.76           5.32
#
#           player_name  batter  pitcher events description  ...  fld_score  \
# 3363  Tuivailala, Sam  448605   592815    NaN        ball  ...          8
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3363                3                8               3               8
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3363              Standard              Standard       226                0.0
#
#      delta_run_exp
# 3363         0.015
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==3346]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3346         SL 2017-06-16           86.8          -2.12            5.5
#
#           player_name  batter  pitcher events description  ...  fld_score  \
# 3346  Tuivailala, Sam  592518   592815    NaN        foul  ...         10
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3346               10                1               1              10
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3346              Standard              Standard       235                0.0
#
#      delta_run_exp
# 3346        -0.022
#
# [1 rows x 92 columns]

# %%
data_sam.loc[data_sam.index==3380]
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3380         SL 2017-06-20           87.7          -1.83           5.49
#
#           player_name  batter  pitcher  events    description  ...  fld_score  \
# 3380  Tuivailala, Sam  435062   592815  single  hit_into_play  ...          8
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3380                8                1               1               8
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3380              Standard              Standard       127              0.004
#
#      delta_run_exp
# 3380         0.716
#
# [1 rows x 92 columns]

# %%
data_sam_type_si=data_sam_type2.loc[data_sam_type2["pitch_type"]=="SI"]

# %%
data_sam_type_si
# Out:
#      pitch_type  spin_axis
# 3195         SI        245
# 2250         SI        243
# 2482         SI        240
# 3208         SI        235
# 4377         SI        236
# 2134         SI        250
# 2555         SI        229
# 3702         SI        232
# 4411         SI        237
# 4862         SI        238
# 3225         SI        237
# 4394         SI        239
# 1810         SI        237
# 2100         SI        232
# 2190         SI        241
# 2261         SI        245
# 4054         SI        235
# 4235         SI        251
# 3028         SI        239
# 3940         SI        228
# 4170         SI        228
# 2615         SI        240
# 2661         SI        249
# 3006         SI        240
# 3221         SI        235
# 3411         SI        236

# %%
data_sam_type_si.describe()
# Out:
#         spin_axis
# count   26.000000
# mean   238.346154
# std      6.222169
# min    228.000000
# 25%    235.000000
# 50%    237.500000
# 75%    240.750000
# max    251.000000
